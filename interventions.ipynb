# %%
import os
import pandas as pd
import numpy as np
import csv
import matplotlib.pyplot as plt

# %%
csv_data = pd.read_csv('interventions.csv')
df = pd.DataFrame(csv_data)
df.head()
# Out:
#    id intervention_type                                       intervention  \
# 0   1            Others  Stregthen/Conduct of Poultry Production and He...
# 1   2            Others                     Training on Integrated Farming
# 2   3            Others  Development of multiplier farms to increase th...
# 3   4            Others                        Dispersal of Native Chicken
# 4   5            Others                  Provision of certified rice seeds
#
#   intervention_others                 intervention_details  multi_year  \
# 0                 NaN            No. of training conducted           0
# 1                 NaN  No. of integrated farming conducted           0
# 2                 NaN     No of multiplier farms developed           0
# 3                 NaN      No. of native chicken dispersed           0
# 4                 NaN  No of certified rice seeds provided           0
#
#    target_1  target_2  target_3  target_4  ...  operating_unit_id  \
# ...

# %%
grouped_data = df.groupby(['region_id'])['investment_total'].sum()
grouped_data_keys = grouped_data.tolist('keys')
grouped_data_values = grouped_data.values.tolist()
print(grouped_data)
# print(type(grouped_data))
plt.bar(grouped_data[1], grouped_data[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-59ce66c3bc09> in <module>
#       1 grouped_data = df.groupby(['region_id'])['investment_total'].sum()
# ----> 2 grouped_data_keys = grouped_data.tolist(keys)
#       3 grouped_data_values = grouped_data.values.tolist()
#       4 print(grouped_data)
#       5 # print(type(grouped_data))
#
# NameError: name 'keys' is not defined
